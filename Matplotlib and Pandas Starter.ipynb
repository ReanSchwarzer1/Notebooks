# %% [markdown]
# <a href="https://colab.research.google.com/github/ReanSchwarzer1/Notebooks/blob/master/Matplotlib%20and%20Pandas%20Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib

# %%
# %matplotlib inline # Make matplotlib work with Jupyter notebooks

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20]) # xmin, xmax, ymin, ymax
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(1, 3, 1) # Total 1 rows, 3 columns and this is the first plot
plt.bar(names, values)
plt.subplot(1, 3, 2)
plt.scatter(names, values)
plt.subplot(1, 3, 3)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ### Multiple figures and axis

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(2, 1, 2)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(2,1,k1)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(2, 1, 2)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(2, 1, 1)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %% [markdown]
# ### Adding text

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability', fontsize=14, color='red')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
fig = plt.figure()
ax = plt.subplot(1,1,1)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
fig.savefig('text.png')

# %% [markdown]
# ### Images with matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np


img = Image.open("./logo.png")
img2 = Image.open("./logo2.png")

# %%
plt.imshow(img)

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 2
rows = 1

location = ['./logo.png', './logo2.png']

for i in range(columns*rows):
    img = Image.open(location[i])
#     fig.add_subplot(rows, columns, i+1)
    plt.figure()
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Pandas

# %%
# Series is a one-dimensional labeled array capable of holding 
# any data type
import pandas as pd

s = pd.Series(np.random.randint(5, size=10))

# %% [markdown]
# Here, data can be many different things:
#
#     a Python dict
#
#     an numpy array
#
#     a scalar value (like 5)

# %%
s
# Out:
# 0    2
# 1    3
# 2    0
# 3    1
# 4    4
# 5    2
# 6    3
# 7    2
# 8    4
# 9    3
# dtype: int64

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:
#
#     Dict of 1D ndarrays, lists, dicts, or Series
#
#     2-D numpy.ndarray
#
#     Structured or record ndarray
#
#     A Series
#
#     Another DataFrame

# %%
df_new = pd.read_csv("./heart.csv")

df_new.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df_new['age'] # Series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df_new.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
simple = np.arange(303)

df_new['simple'] = simple

df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
df_new.iloc[:3, :2] # Row and column index
# Out:
#    age  sex
# 0   63    1
# 1   37    1
# 2   41    0

# %%
df_new.loc[:3, :'sex']
# Out:
#    age  sex
# 0   63    1
# 1   37    1
# 2   41    0
# 3   56    1

# %%
# Masking as indexing

df_new.loc[df_new['age']>60, ['sex', 'cp']]
# Out:
#      sex  cp
# 0      1   3
# 13     1   3
# 17     0   3
# 19     0   3
# 23     1   2
# ..   ...  ..
# 290    1   0
# 293    1   2
# 295    1   0
# 296    0   0
# 300    1   0
#
# [79 rows x 2 columns]

# %%
df_new.iloc[0, 0] = 90

df_new.head(1)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target  simple
# 0   0     1       1       0

# %%
df_new.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target', 'simple'],
#       dtype='object')

# %%
df_new.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# simple        int64
# dtype: object

# %%
df_new.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.455446    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.297003    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     90.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target      simple
# count  303.000000  303.000000  303.000000
# mean     2.313531    0.544554  151.000000
# std      0.612277    0.498835   87.612784
# min      0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   75.500000
# 50%      2.000000    1.000000  151.000000
# 75%      3.000000    1.000000  226.500000
# max      3.000000    1.000000  302.000000

# %%
df_new.sort_values(by='age')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 125   34    0   1       118   210    0        1      192      0      0.7
# 58    34    1   3       118   182    0        0      174      0      0.0
# 157   35    1   1       122   192    0        1      174      0      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 25    71    0   1       160   302    0        1      162      0      0.4
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 238   77    1   0       125   304    0        0      162      1      0.0
# 0     90    1   3       145   233    1        0      150      0      2.3
#
#      slope  ca  thal  target  simple
# 72       2   0     2       1      72
# 125      2   0     2       1     125
# 58       2   0     2       1      58
# 157      2   0     2       1     157
# 65       2   0     2       1      65
# ..     ...  ..   ...     ...     ...
# 25       2   2     2       1      25
# 129      2   1     2       1     129
# 144      1   0     2       1     144
# 238      2   3     2       0     238
# 0        0   0     1       1       0
#
# [303 rows x 15 columns]

# %%
df_new.dropna(axis=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# 1        0   0     2       1       1
# 2        2   0     2       1       2
# 3        2   0     2       1       3
# 4        2   0     2       1       4
# ..     ...  ..   ...     ...     ...
# 298      1   0     3       0     298
# 299      1   0     3       0     299
# 300      1   2     3       0     300
# 301      1   1     3       0     301
# 302      1   1     2       0     302
#
# [303 rows x 15 columns]

# %%
df_new.fillna(value = 5, axis=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# 1        0   0     2       1       1
# 2        2   0     2       1       2
# 3        2   0     2       1       3
# 4        2   0     2       1       4
# ..     ...  ..   ...     ...     ...
# 298      1   0     3       0     298
# 299      1   0     3       0     299
# 300      1   2     3       0     300
# 301      1   1     3       0     301
# 302      1   1     2       0     302
#
# [303 rows x 15 columns]

# %%
df_new.mean()
# Out:
# age          54.455446
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# simple      151.000000
# dtype: float64

# %%
df_new.apply(np.sqrt)
# Out:
#           age  sex        cp   trestbps       chol  fbs  restecg    thalach  \
# 0    9.486833  1.0  1.732051  12.041595  15.264338  1.0      0.0  12.247449
# 1    6.082763  1.0  1.414214  11.401754  15.811388  0.0      1.0  13.674794
# 2    6.403124  0.0  1.000000  11.401754  14.282857  0.0      0.0  13.114877
# 3    7.483315  1.0  1.000000  10.954451  15.362291  0.0      1.0  13.341664
# 4    7.549834  0.0  0.000000  10.954451  18.814888  0.0      1.0  12.767145
# ..        ...  ...       ...        ...        ...  ...      ...        ...
# 298  7.549834  0.0  0.000000  11.832160  15.524175  0.0      1.0  11.090537
# 299  6.708204  1.0  1.732051  10.488088  16.248077  0.0      1.0  11.489125
# 300  8.246211  1.0  0.000000  12.000000  13.892444  1.0      1.0  11.874342
# 301  7.549834  1.0  0.000000  11.401754  11.445523  0.0      1.0  10.723805
# 302  7.549834  0.0  1.000000  11.401754  15.362291  0.0      0.0  13.190906
#
#      exang   oldpeak     slope        ca      thal  target     simple
# 0      0.0  1.516575  0.000000  0.000000  1.000000     1.0   0.000000
# 1      0.0  1.870829  0.000000  0.000000  1.414214     1.0   1.000000
# 2      0.0  1.183216  1.414214  0.000000  1.414214     1.0   1.414214
# 3      0.0  0.894427  1.414214  0.000000  1.414214     1.0   1.732051
# 4      1.0  0.774597  1.414214  0.000000  1.414214     1.0   2.000000
# ..     ...       ...       ...       ...       ...     ...        ...
# 298    1.0  0.447214  1.000000  0.000000  1.732051     0.0  17.262677
# 299    0.0  1.095445  1.000000  0.000000  1.732051     0.0  17.291616
# 300    0.0  1.843909  1.000000  1.414214  1.732051     0.0  17.320508
# 301    1.0  1.095445  1.000000  1.000000  1.732051     0.0  17.349352
# 302    0.0  0.000000  1.000000  1.000000  1.414214     0.0  17.378147
#
# [303 rows x 15 columns]

# %%
df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
pieces = [df_new[:30], df_new[30:]]

pd.concat(pieces)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# 1        0   0     2       1       1
# 2        2   0     2       1       2
# 3        2   0     2       1       3
# 4        2   0     2       1       4
# ..     ...  ..   ...     ...     ...
# 298      1   0     3       0     298
# 299      1   0     3       0     299
# 300      1   2     3       0     300
# 301      1   1     3       0     301
# 302      1   1     2       0     302
#
# [303 rows x 15 columns]

# %%
left = pd.DataFrame({'key': ['foo1', 'foo2'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo1', 'foo2'], 'rval': [4, 5]})
left
# Out:
#     key  lval
# 0  foo1     1
# 1  foo2     2

# %%
right
# Out:
#     key  rval
# 0  foo1     4
# 1  foo2     5

# %%
pd.merge(left, right, on='key')
# Out:
#     key  lval  rval
# 0  foo1     1     4
# 1  foo2     2     5

# %%
df_new.groupby('age').mean().head()
# Out:
#       sex        cp  trestbps        chol  fbs  restecg  thalach     exang  \
# age
# 29   1.00  1.000000     130.0  204.000000  0.0     0.00    202.0  0.000000
# 34   0.50  2.000000     118.0  196.000000  0.0     0.50    183.0  0.000000
# 35   0.75  0.250000     126.5  213.750000  0.0     0.75    160.5  0.500000
# 37   0.50  2.000000     125.0  232.500000  0.0     1.00    178.5  0.000000
# 38   1.00  2.333333     132.0  193.666667  0.0     1.00    176.0  0.333333
#
#       oldpeak     slope        ca      thal    target      simple
# age
# 29   0.000000  2.000000  0.000000  2.000000  1.000000   72.000000
# 34   0.350000  2.000000  0.000000  2.000000  1.000000   91.500000
# 35   0.750000  1.750000  0.000000  2.500000  0.500000  172.000000
# 37   1.750000  1.000000  0.000000  2.000000  1.000000   58.000000
# 38   1.266667  1.666667  2.666667  2.333333  0.666667  195.333333

# %%
df_new.to_csv("./hearts2.csv")
